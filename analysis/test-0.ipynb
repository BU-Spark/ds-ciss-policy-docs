# %%
# !pwd
# Out:
# /home/haodong/working/ds-ciss-policy-docs/analysis

# %%
import pandas as pd
df = pd.read_csv('./shanghai-2022.csv')
df.head()
# Out:
#                id                                           filename  \
# 0  CLI.12.5488773  ../../data/shanghai/2022/上海仲裁委员会仲裁规则(2022修订)(F...
# 1  CLI.12.5557816  ../../data/shanghai/2022/上海仲裁委员会章程(2022修订)(FBM...
# 2  CLI.12.4848732  ../../data/shanghai/2022/上海保险交易所保险中介服务平台收费标准(试...
# 3  CLI.12.4861245  ../../data/shanghai/2022/上海国际能源交易中心发布关于SC2203合...
# 4  CLI.12.4923439  ../../data/shanghai/2022/上海国际能源交易中心发布关于SC2204合...
#
#                                                  url    type
# 0  https://www.pkulaw.com/lar/07f795f96a47fd4720d...    仲裁机构
# 1  https://www.pkulaw.com/lar/cd2d7c3db77598534dd...    仲裁机构
# 2  https://www.pkulaw.com/lar/6652ebf373903d7f1fa...  保险综合规定
# 3  https://www.pkulaw.com/lar/c031ef477fdc3de2bc7...  期货综合规定
# 4  https://www.pkulaw.com/lar/1bdeb4aa2ee86d0c358...  期货综合规定

# %%
categories = df['type'].unique()
print(df.shape, len(categories))
categories
# Out:
# (942, 4) 250
# array(['仲裁机构', '保险综合规定', '期货综合规定', '能源综合规定', '交通运输综合规定', '专项资金管理', '船舶',
#        '城市交通运输', '交通安全管理', '市政公用与路桥营商环境优化', '市政公用与路桥', '港口港务', '建筑安装施工',
#        '行政处罚与行政复议', '土地征用与有偿使用赡养抚养收养', '社会福利与社会保障', '职位职称', '招工与就业',
#        '社会福利与社会保障老少妇幼残保护', '劳动工会综合规定工资福利与劳动保险', '劳动工会综合规定',
#        '人事综合规定营商环境优化', '出国留学与回国工作', '户籍与身份证', '服务', '机关工作综合规定',
#        '对外开放与鼓励外商投资', '法制工作综合规定', '老少妇幼残保护', '农业管理', '体育综合规定', '教育综合规定',
#        '职业与职工教育', '劳动安全与劳动保护', '农民工营商环境优化', '招工与就业社会福利与社会保障', '区域经济开发',
#        '法规规章清理', '区域经济开发营商环境优化', '气象综合规定', '卫生综合规定营商环境优化', '行业计划',
#        '资本项目综合', '财政综合规定', '工资福利与劳动保险营商环境优化', '土地征用与有偿使用', '计划生育统计财会',
#        '外国公司营商环境优化', '税收征收管理', '房地产综合规定', '价格综合规定', '公安综合规定',
#        '行政处罚与行政复议营商环境优化', '自然保护', '机关工作综合规定营商环境优化', '奖惩', '药品管理',
#        '质量综合规定', '交通运输综合规定营商环境优化', '科技综合规定与体改', '对外经贸综合规定', '科学研究与科技项目',
#        '商贸物资综合规定', '城市规划与开发建设', '林业管理', '宏观经济体制改革', '商贸物资综合规定营商环境优化',
# ...

# %%
import pandas as pd
df = pd.read_csv('./cate.csv')
df.head()
# Out:
#                id      area  year  \
# 0  CLI.12.5488773  shanghai  2022
# 1  CLI.12.5557816  shanghai  2022
# 2  CLI.12.4848732  shanghai  2022
# 3  CLI.12.4861245  shanghai  2022
# 4  CLI.12.4923439  shanghai  2022
#
#                                             filename  \
# 0        上海仲裁委员会仲裁规则(2022修订)(FBM-CLI.12.5488773).txt
# 1          上海仲裁委员会章程(2022修订)(FBM-CLI.12.5557816).txt
# 2   上海保险交易所保险中介服务平台收费标准(试...(FBM-CLI.12.4848732).txt
# 3  上海国际能源交易中心发布关于SC2203合约临近交割...(FBM-CLI.12.48612...
# 4  上海国际能源交易中心发布关于SC2204合约临近交割...(FBM-CLI.12.49234...
#
#                                                  url    type
# 0  https://www.pkulaw.com/lar/07f795f96a47fd4720d...    仲裁机构
# 1  https://www.pkulaw.com/lar/cd2d7c3db77598534dd...    仲裁机构
# 2  https://www.pkulaw.com/lar/6652ebf373903d7f1fa...  保险综合规定
# 3  https://www.pkulaw.com/lar/c031ef477fdc3de2bc7...  期货综合规定
# 4  https://www.pkulaw.com/lar/1bdeb4aa2ee86d0c358...  期货综合规定

# %%
categories = df['type'].unique()
print(df.shape, len(categories))
categories
# Out:
# (2296, 6) 564
# array(['仲裁机构', '保险综合规定', '期货综合规定', '能源综合规定', '交通运输综合规定', '专项资金管理', '船舶',
#        '城市交通运输', '交通安全管理', '市政公用与路桥营商环境优化', '市政公用与路桥', '港口港务', '建筑安装施工',
#        '行政处罚与行政复议', '土地征用与有偿使用赡养抚养收养', '社会福利与社会保障', '职位职称', '招工与就业',
#        '社会福利与社会保障老少妇幼残保护', '劳动工会综合规定工资福利与劳动保险', '劳动工会综合规定',
#        '人事综合规定营商环境优化', '出国留学与回国工作', '户籍与身份证', '服务', '机关工作综合规定',
#        '对外开放与鼓励外商投资', '法制工作综合规定', '老少妇幼残保护', '农业管理', '体育综合规定', '教育综合规定',
#        '职业与职工教育', '劳动安全与劳动保护', '农民工营商环境优化', '招工与就业社会福利与社会保障', '区域经济开发',
#        '法规规章清理', '区域经济开发营商环境优化', '气象综合规定', '卫生综合规定营商环境优化', '行业计划',
#        '资本项目综合', '财政综合规定', '工资福利与劳动保险营商环境优化', '土地征用与有偿使用', '计划生育统计财会',
#        '外国公司营商环境优化', '税收征收管理', '房地产综合规定', '价格综合规定', '公安综合规定',
#        '行政处罚与行政复议营商环境优化', '自然保护', '机关工作综合规定营商环境优化', '奖惩', '药品管理',
#        '质量综合规定', '交通运输综合规定营商环境优化', '科技综合规定与体改', '对外经贸综合规定', '科学研究与科技项目',
#        '商贸物资综合规定', '城市规划与开发建设', '林业管理', '宏观经济体制改革', '商贸物资综合规定营商环境优化',
# ...
