# %%
! unzip -O CP936 '*.zip' -d ./origin/
# Out:
# Archive:  Set-1_0320.zip
#   inflating: ./origin/Regulatory Statute Documents Set 1/.DS_Store
#   inflating: ./origin/Regulatory Statute Documents Set 1/山西规范性文件/.DS_Store
#   inflating: ./origin/Regulatory Statute Documents Set 1/黑龙江规范性文件/.DS_Store
#   inflating: ./origin/Regulatory Statute Documents Set 1/江苏规范性文件/.DS_Store
#   inflating: ./origin/Regulatory Statute Documents Set 1/浙江规范性文件/.DS_Store
#   inflating: ./origin/Regulatory Statute Documents Set 1/上海规范性文件/.DS_Store
#   inflating: ./origin/Regulatory Statute Documents Set 1/内蒙规范性文件/.DS_Store
#   inflating: ./origin/Regulatory Statute Documents Set 1/吉林规范性文件/.DS_Store
#   inflating: ./origin/Regulatory Statute Documents Set 1/辽宁规范性文件/.DS_Store
#   inflating: ./origin/Regulatory Statute Documents Set 1/北京规范性文件/.DS_Store
#   inflating: ./origin/Regulatory Statute Documents Set 1/河北规范性文件/.DS_Store
#   inflating: ./origin/Regulatory Statute Documents Set 1/天津规范性文件/.DS_Store
# ...

# %%
import os
cwd = os.path.dirname(os.path.realpath(__file__))
root, dirs, files = next(os.walk(os.path.join(cwd, "origin")))
dirs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 import os
# ----> 2 cwd = os.path.dirname(os.path.realpath(__file__))
#       3 root, dirs, files = next(os.walk(os.path.join(cwd, "origin")))
#       4 dirs
#
# NameError: name '__file__' is not defined

# %%
from pypinyin import lazy_pinyin

# %%
lazy_pinyin('中心')
# Out:
# ['zhong', 'xin']
